# %%
# pip install eurostatapiclient
# !pip install eurostat
# Out:
# ...
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# ...
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# ...
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# ...
#   Using cached numpy-1.24.4-cp38-cp38-win_amd64.whl (14.9 MB)
# ...
#   Using cached urllib3-2.0.3-py3-none-any.whl (123 kB)
# ...
#   Using cached certifi-2023.5.7-py3-none-any.whl (156 kB)
# ...
# WARNING: You are using pip version 21.3.1; however, version 23.1.2 is available.
# You should consider upgrading via the 'C:\Users\ptroulitaki\PycharmProjects\ITML Projects\enisa\datacollectionmodule\venv_python\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# from eurostatapiclient import EurostatAPIClient
import eurostat

# %%
test=eurostat.get_dic(code = 'ISOC_CISCE_RA', par='indic_is')

# %%
test =dict(test)

# %%
test['E_SECMSPSW']
# Out:
# 'ICT security measure used: strong password authentication'

# %%
toc = eurostat.get_toc_df()

# %%
toc.loc[toc['code'] == 'ISOC_CISCI_PRV20']
# Out:
#                                                   title              code  \
# 1240  Privacy and protection of personal data (2020 ...  ISOC_CISCI_PRV20
#
#          type       last update of data last table structure change  \
# 1240  dataset  2023-07-10T11:00:00+0200    2023-03-07T11:00:00+0100
#
#      data start data end
# 1240       2020     2021

# %% [markdown]
# ### Indicator 2.6 - Privacy and protection of personal data (citizens’ view)

# %%
eurostat.subset_toc_df(toc, 'privacy')
# Out:
#                                                   title              code  \
# 4590  Privacy and protection of personal information...    ISOC_CISCI_PRV
# 4593  Privacy and protection of personal data (2020 ...  ISOC_CISCI_PRV20
# 4597   Trust, security and privacy - smartphones (2018)     ISOC_CISCI_SP
# 4600  Trust, security and privacy - smartphones (202...   ISOC_CISCI_SP20
#
#          type       last update of data last table structure change  \
# 4590  dataset  2023-01-12T23:00:00+0100    2021-02-08T23:00:00+0100
# 4593  dataset  2023-01-12T23:00:00+0100    2022-03-30T11:00:00+0200
# 4597  dataset  2023-01-12T23:00:00+0100    2021-02-08T23:00:00+0100
# 4600  dataset  2023-01-12T23:00:00+0100    2022-03-30T11:00:00+0200
#
#      data start data end
# 4590       2015     2016
# 4593       2020     2021
# 4597       2018     2018
# 4600       2020     2020

# %%
eurostat.get_pars('ISOC_CISCI_PRV20')
# Out:
# ['freq', 'ind_type', 'indic_is', 'unit', 'geo']

# %%
eurostat.get_par_values('ISOC_CISCI_PRV20', 'indic_is')
# Out:
# ['I_COOK1',
#  'I_PCOOK1',
#  'I_USLCOOK',
#  'I_MAPS_RPS',
#  'I_MAPS_RRGL',
#  'I_MAPS_LAP',
#  'I_MAPS_RAAD',
#  'I_MAPS_CWSC',
#  'I_MAPS_APD',
#  'I_MAPS_3',
#  'I_MAPS_5',
#  'I_MAPS']

# %%
eurostat.get_par_values('ISOC_CISCI_PRV20', 'ind_type')
# Out:
# ['IND_TOTAL',
#  'Y0_15',
#  'Y16_24',
#  'Y25_34',
#  'Y25_54',
#  'Y25_64',
#  'Y35_44',
#  'Y45_54',
#  'Y55_64',
#  'Y55_74',
#  'Y65_74',
#  'Y75_MAX',
#  'Y16_24LO',
#  'Y16_24ME',
#  'Y16_24HI',
#  'Y25_54LO',
#  'Y25_54ME',
#  'Y25_54HI',
#  'Y25_64LO',
#  'Y25_64ME',
#  'Y25_64HI',
#  'Y55_74LO',
#  'Y55_74ME',
#  'Y55_74HI',
#  'Y25_64_SALSELFFAM',
#  'Y25_64_UNE',
#  'Y25_64_EMPL_UNE',
#  'Y25_64_RETIROTH',
#  'M_Y16_24',
#  'F_Y16_24',
#  'M_Y16_74',
#  'F_Y16_74',
#  'M_Y25_54',
#  'F_Y25_54',
#  'M_Y25_64',
#  'F_Y25_64',
#  'M_Y55_74',
#  'F_Y55_74',
#  'M_I0_2',
#  'F_I0_2',
#  'M_I3_4',
#  'F_I3_4',
#  'M_I5_8',
#  'F_I5_8',
#  'I0_2',
#  'I3_4',
#  'I5_8',
#  'CB_EU_FOR',
#  'CB_EXT_EU',
#  'CB_FOR',
#  'CB_NAT',
#  'CC_EU_FOR',
#  'CC_EXT_EU',
#  'CC_FOR',
#  'CC_NAT',
#  'EMPL_UNE',
#  'HHI_Q1',
#  'HHI_Q2',
#  'HHI_Q3',
#  'HHI_Q4',
#  'IND_DEG1',
#  'IND_DEG2',
#  'IND_DEG3',
#  'IND_BROAD',
#  'IND_BROADX',
#  'ISCO_ICT',
#  'ISCO_ICTX',
#  'ISCO0_5',
# ...

# %%
eurostat.get_par_values('ISOC_CISCI_PRV20', 'freq')
# Out:
# ['A']

# %%
eurostat.get_par_values('ISOC_CISCI_PRV20', 'unit')
# Out:
# ['PC_IND', 'PC_IND_IU3']

# %%
eurostat.get_par_values('ISOC_CISCI_PRV20', 'geo')
# Out:
# ['EU27_2020',
#  'EA',
#  'BE',
#  'BG',
#  'CZ',
#  'DK',
#  'DE',
#  'EE',
#  'IE',
#  'EL',
#  'ES',
#  'FR',
#  'HR',
#  'IT',
#  'CY',
#  'LV',
#  'LT',
#  'LU',
#  'HU',
#  'MT',
#  'NL',
#  'AT',
#  'PL',
#  'PT',
#  'RO',
#  'SI',
#  'SK',
#  'FI',
#  'SE',
#  'IS',
#  'NO',
#  'CH',
#  'UK',
#  'ME',
#  'MK',
#  'AL',
#  'RS',
#  'TR',
#  'BA',
#  'XK']

# %%
code = 'ISOC_CISCI_PRV20'
pars = eurostat.get_pars(code)
countries = ['AT','BE','BG','HR','CY','CZ','DK','EE','FI','FR','DE','EL','HU','IE','IT','LV','LT','LU','MT','NL','PL','PT','RO','SK','SI','ES','SE']

# %%
my_filter_pars = {'ind_type': 'IND_TOTAL', 'unit': 'PC_IND', 'indic_is':'I_MAPS_5', 'geo': countries, 'startPeriod': 2021, 'endPeriod':2022}
data = eurostat.get_data_df(code, filter_pars=my_filter_pars)

# %%
data
# Out:
#    freq   ind_type  indic_is    unit geo\TIME_PERIOD   2021
# 0     A  IND_TOTAL  I_MAPS_5  PC_IND              AT  75.69
# 1     A  IND_TOTAL  I_MAPS_5  PC_IND              BE  60.06
# 2     A  IND_TOTAL  I_MAPS_5  PC_IND              BG  46.67
# 3     A  IND_TOTAL  I_MAPS_5  PC_IND              HR  68.66
# 4     A  IND_TOTAL  I_MAPS_5  PC_IND              CY  68.25
# 5     A  IND_TOTAL  I_MAPS_5  PC_IND              CZ  73.79
# 6     A  IND_TOTAL  I_MAPS_5  PC_IND              DK  81.62
# 7     A  IND_TOTAL  I_MAPS_5  PC_IND              EE  63.95
# 8     A  IND_TOTAL  I_MAPS_5  PC_IND              FI  87.92
# 9     A  IND_TOTAL  I_MAPS_5  PC_IND              FR  71.24
# 10    A  IND_TOTAL  I_MAPS_5  PC_IND              DE  63.01
# 11    A  IND_TOTAL  I_MAPS_5  PC_IND              EL  58.71
# 12    A  IND_TOTAL  I_MAPS_5  PC_IND              HU  64.34
# 13    A  IND_TOTAL  I_MAPS_5  PC_IND              IE  78.55
# 14    A  IND_TOTAL  I_MAPS_5  PC_IND              IT  56.59
# ...

# %% [markdown]
# ### Indicator 2.14 - % of organisations and enterprises performing a risk assessment

# %%
code = 'ISOC_CISCE_RA'
pars = eurostat.get_pars(code)

# %%
pars
# Out:
# ['freq', 'size_emp', 'nace_r2', 'indic_is', 'unit', 'geo']

# %%
eurostat.get_par_values(code, 'size_emp')
# Out:
# ['0_1',
#  '0-9',
#  '1-4',
#  '1-9',
#  '2-9',
#  '5-9',
#  '10-49',
#  '10-249',
#  'GE10',
#  '50-249',
#  'GE250']

# %%
my_filter_pars = {'size_emp': 'GE10', 'indic_is': 'E_SECMRASS', 'unit':'PC_ENT', 'geo': countries, 'startPeriod': 2019, 'endPeriod':2019}
data = eurostat.get_data_df(code, filter_pars=my_filter_pars)

# %%
data
# Out:
#    freq size_emp       nace_r2    indic_is    unit geo\TIME_PERIOD  2019
# 0     A     GE10  C10-S951_X_K  E_SECMRASS  PC_ENT              AT  28.4
# 1     A     GE10  C10-S951_X_K  E_SECMRASS  PC_ENT              BE  43.4
# 2     A     GE10  C10-S951_X_K  E_SECMRASS  PC_ENT              BG  23.1
# 3     A     GE10  C10-S951_X_K  E_SECMRASS  PC_ENT              HR  24.4
# 4     A     GE10  C10-S951_X_K  E_SECMRASS  PC_ENT              CY  34.9
# 5     A     GE10  C10-S951_X_K  E_SECMRASS  PC_ENT              CZ  36.6
# 6     A     GE10  C10-S951_X_K  E_SECMRASS  PC_ENT              DK  49.3
# 7     A     GE10  C10-S951_X_K  E_SECMRASS  PC_ENT              EE  23.1
# 8     A     GE10  C10-S951_X_K  E_SECMRASS  PC_ENT              FI  59.7
# 9     A     GE10  C10-S951_X_K  E_SECMRASS  PC_ENT              FR  33.0
# 10    A     GE10  C10-S951_X_K  E_SECMRASS  PC_ENT              DE  33.6
# 11    A     GE10  C10-S951_X_K  E_SECMRASS  PC_ENT              EL  24.9
# ...

# %%
my_filter_pars = {'size_emp': '10-249', 'indic_is': 'E_SECMRASS', 'unit':'PC_ENT', 'geo': countries, 'startPeriod': 2019, 'endPeriod':2022}
data = eurostat.get_data_df(code, filter_pars=my_filter_pars)

# %%
data
# Out:
#    freq size_emp       nace_r2    indic_is    unit geo\TIME_PERIOD  2019  2022
# 0     A   10-249  C10-S951_X_K  E_SECMRASS  PC_ENT              AT  27.2  30.7
# 1     A   10-249  C10-S951_X_K  E_SECMRASS  PC_ENT              BE  42.1  43.7
# 2     A   10-249  C10-S951_X_K  E_SECMRASS  PC_ENT              BG  22.3  15.5
# 3     A   10-249  C10-S951_X_K  E_SECMRASS  PC_ENT              HR  23.5  18.7
# 4     A   10-249  C10-S951_X_K  E_SECMRASS  PC_ENT              CY  34.0  37.2
# 5     A   10-249  C10-S951_X_K  E_SECMRASS  PC_ENT              CZ  35.0  33.9
# 6     A   10-249  C10-S951_X_K  E_SECMRASS  PC_ENT              DK  48.2  54.2
# 7     A   10-249  C10-S951_X_K  E_SECMRASS  PC_ENT              EE  22.1  27.3
# 8     A   10-249  C10-S951_X_K  E_SECMRASS  PC_ENT              FI  58.8  57.8
# 9     A   10-249  C10-S951_X_K  E_SECMRASS  PC_ENT              FR  31.8  24.9
# 10    A   10-249  C10-S951_X_K  E_SECMRASS  PC_ENT              DE  32.4  36.2
# ...

# %% [markdown]
# ### Indicator 2.25 - Percentage of enterprises in a country covered by insurance against ICT-related incidents

# %%
code = 'ISOC_CISCE_IC'
pars = eurostat.get_pars(code)

# %%
pars
# Out:
# ['freq', 'size_emp', 'nace_r2', 'indic_is', 'unit', 'geo']

# %%
eurostat.get_par_values(code, 'indic_is')
# Out:
# ['E_SEC2IUSVF',
#  'E_SEC2IUSVA',
#  'E_SEC2IUSV',
#  'E_SEC2IDCDF',
#  'E_SEC2IDCDA',
#  'E_SEC2IDCD',
#  'E_SEC2ICNFA',
#  'E_SEC2ICNFF',
#  'E_SEC2ICNF',
#  'E_SEC2IANY',
#  'E_SEC2IGE3',
#  'E_SECI2USV',
#  'E_SECI2DCD',
#  'E_SECI2CNF',
#  'E_SECI2ANY',
#  'E_SECI2NONE',
#  'E_SECIUSF',
#  'E_SECIUSA',
#  'E_SECIDD',
#  'E_SECICNFA',
#  'E_SECIANY',
#  'E_SECINONE',
#  'E_SECICNFE',
#  'E_SECINS']

# %%
my_filter_pars = {'size_emp': 'GE10', 'indic_is': 'E_SECINS', 'unit':'PC_ENT', 'geo': countries, 'startPeriod': 2019, 'endPeriod':2019}
data = eurostat.get_data_df(code, filter_pars=my_filter_pars)

# %%
data
# Out:
#    freq size_emp       nace_r2  indic_is    unit geo\TIME_PERIOD  2019
# 0     A     GE10  C10-S951_X_K  E_SECINS  PC_ENT              AT  17.8
# 1     A     GE10  C10-S951_X_K  E_SECINS  PC_ENT              BE  24.8
# 2     A     GE10  C10-S951_X_K  E_SECINS  PC_ENT              BG   2.8
# 3     A     GE10  C10-S951_X_K  E_SECINS  PC_ENT              HR   7.3
# 4     A     GE10  C10-S951_X_K  E_SECINS  PC_ENT              CY  13.2
# 5     A     GE10  C10-S951_X_K  E_SECINS  PC_ENT              CZ   8.4
# 6     A     GE10  C10-S951_X_K  E_SECINS  PC_ENT              DK  55.7
# 7     A     GE10  C10-S951_X_K  E_SECINS  PC_ENT              EE   6.6
# 8     A     GE10  C10-S951_X_K  E_SECINS  PC_ENT              FI  27.5
# 9     A     GE10  C10-S951_X_K  E_SECINS  PC_ENT              FR  39.1
# 10    A     GE10  C10-S951_X_K  E_SECINS  PC_ENT              DE  20.4
# 11    A     GE10  C10-S951_X_K  E_SECINS  PC_ENT              EL  25.4
# ...

# %% [markdown]
# ### Indicator 3.8 - Enterprises ICT security measures

# %%
code = 'ISOC_CISCE_RA'
pars = eurostat.get_pars(code)

# %%
pars
# Out:
# ['freq', 'size_emp', 'nace_r2', 'indic_is', 'unit', 'geo']

# %%
eurostat.get_par_values(code, 'indic_is')
# Out:
# ['E_SECMSPSW',
#  'E_SECMKSUD',
#  'E_SECMUIBM',
#  'E_SECMDENC',
#  'E_SECMOSBU',
#  'E_SECMNAC',
#  'E_SECMVPN',
#  'E_SECMLOG',
#  'E_SECMRASS',
#  'E_SECMTST',
#  'E_SECMANY',
#  'E_SECMDUO',
#  'E_SECMSMS',
#  'E_SECMGE1',
#  'E_SECMGE3',
#  'E_SECMGE5',
#  'E_SECMGE7',
#  'E_SECMALL',
#  'E_SECPOL1',
#  'E_SECPREV_CY',
#  'E_SECPREV_1_2',
#  'E_SECPREV_MT2',
#  'E_SECPREV_LE2',
#  'E_SECPOL',
#  'E_SECPOL2',
#  'E_SECPAR',
#  'E_SECPSPAP',
#  'E_SECPPR',
#  'E_SECPRRD',
#  'E_SECPTRA',
#  'E_SECPDD',
#  'E_SECPCNF',
#  'E_SECPDS',
#  'E_SECPALL',
#  'E_SECAWVTGI',
#  'E_SECAWCTP',
#  'E_SECAWCONT',
#  'E_SECAWANY',
#  'E_SECAWNONE',
#  'E_SECCTP',
#  'E_SECCONT',
#  'E_SECNONE',
#  'E_SECANY',
#  'E_SECVTGI',
#  'E_ITSEC3OWN',
#  'E_ITSEC3EXT',
#  'E_ITSEC3']

# %%
my_filter_pars = {'size_emp': 'GE10', 'indic_is': ['E_SECMSPSW', 'E_SECMDUO', 'E_SECMDENC', 'E_SECMOSBU', 'E_SECMNAC','E_SECMVPN', 'E_SECMLOG',
                   'E_SECMTST'], 'unit':'PC_ENT', 'geo': countries, 'startPeriod': 2022, 'endPeriod':2022}
data = eurostat.get_data_df(code, filter_pars=my_filter_pars)

# %%
for i,var in enumerate(data['indic_is'].unique()):
    print(i)
    test=data.loc[data['indic_is'] == var]
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
toc.loc[toc['code'] == code]
# Out:
#                                                   title           code  \
# 5234  Security policy: measures, risks and staff awa...  ISOC_CISCE_RA
#
#          type       last update of data last table structure change  \
# 5234  dataset  2023-06-30T11:00:00+0200    2023-05-25T11:00:00+0200
#
#      data start data end
# 5234       2010     2022

# %%
test
# Out:
#     freq size_emp       nace_r2   indic_is    unit geo\TIME_PERIOD  2022
# 189    A     GE10  C10-S951_X_K  E_SECMTST  PC_ENT              AT  34.6
# 190    A     GE10  C10-S951_X_K  E_SECMTST  PC_ENT              BE  45.2
# 191    A     GE10  C10-S951_X_K  E_SECMTST  PC_ENT              BG  17.8
# 192    A     GE10  C10-S951_X_K  E_SECMTST  PC_ENT              HR  22.2
# 193    A     GE10  C10-S951_X_K  E_SECMTST  PC_ENT              CY  38.9
# 194    A     GE10  C10-S951_X_K  E_SECMTST  PC_ENT              CZ  36.8
# 195    A     GE10  C10-S951_X_K  E_SECMTST  PC_ENT              DK  49.7
# 196    A     GE10  C10-S951_X_K  E_SECMTST  PC_ENT              EE  31.2
# 197    A     GE10  C10-S951_X_K  E_SECMTST  PC_ENT              FI  44.4
# 198    A     GE10  C10-S951_X_K  E_SECMTST  PC_ENT              FR  27.5
# 199    A     GE10  C10-S951_X_K  E_SECMTST  PC_ENT              DE  42.6
# 200    A     GE10  C10-S951_X_K  E_SECMTST  PC_ENT              EL  33.7
# ...

# %%
data.loc[data['indic_is'] == 'E_SECMTST']
# Out:
#     freq size_emp       nace_r2   indic_is    unit geo\TIME_PERIOD  2019
# 215    A     GE10  C10-S951_X_K  E_SECMTST  PC_ENT              AT  31.8
# 216    A     GE10  C10-S951_X_K  E_SECMTST  PC_ENT              BE  46.8
# 217    A     GE10  C10-S951_X_K  E_SECMTST  PC_ENT              BG  22.7
# 218    A     GE10  C10-S951_X_K  E_SECMTST  PC_ENT              HR  26.8
# 219    A     GE10  C10-S951_X_K  E_SECMTST  PC_ENT              CY  36.7
# 220    A     GE10  C10-S951_X_K  E_SECMTST  PC_ENT              CZ  38.7
# 221    A     GE10  C10-S951_X_K  E_SECMTST  PC_ENT              DK  49.3
# 222    A     GE10  C10-S951_X_K  E_SECMTST  PC_ENT              EE  27.8
# 223    A     GE10  C10-S951_X_K  E_SECMTST  PC_ENT              FI  43.7
# 224    A     GE10  C10-S951_X_K  E_SECMTST  PC_ENT              FR  35.1
# 225    A     GE10  C10-S951_X_K  E_SECMTST  PC_ENT              DE  38.7
# 226    A     GE10  C10-S951_X_K  E_SECMTST  PC_ENT              EL  37.2
# ...

# %%
my_filter_pars = {'size_emp': '10-249', 'indic_is': ['E_SECMSPSW','E_SECMKSUD', 'E_SECMUIBM', 'E_SECMDENC', 'E_SECMOSBU', 'E_SECMNAC', 'E_SECMVPN',  'E_SECMLOG','E_SECMTST'], 'unit':'PC_ENT', 'geo': countries, 'startPeriod': 2019, 'endPeriod':2022}
data = eurostat.get_data_df(code, filter_pars=my_filter_pars)

# %%
data.loc[data['indic_is'] == 'E_SECMSPSW']
# Out:
#    freq size_emp       nace_r2    indic_is    unit geo\TIME_PERIOD  2019  2022
# 0     A    10-49  C10-S951_X_K  E_SECMSPSW  PC_ENT              AT  62.6  77.3
# 1     A    10-49  C10-S951_X_K  E_SECMSPSW  PC_ENT              BE  70.9  87.8
# 2     A    10-49  C10-S951_X_K  E_SECMSPSW  PC_ENT              BG  69.7  75.0
# 3     A    10-49  C10-S951_X_K  E_SECMSPSW  PC_ENT              HR  65.0  65.0
# 4     A    10-49  C10-S951_X_K  E_SECMSPSW  PC_ENT              CY  64.5  83.1
# 5     A    10-49  C10-S951_X_K  E_SECMSPSW  PC_ENT              CZ  83.4  84.0
# 6     A    10-49  C10-S951_X_K  E_SECMSPSW  PC_ENT              DK  81.2  83.4
# 7     A    10-49  C10-S951_X_K  E_SECMSPSW  PC_ENT              EE  57.7  67.1
# 8     A    10-49  C10-S951_X_K  E_SECMSPSW  PC_ENT              FI  89.8  93.0
# 9     A    10-49  C10-S951_X_K  E_SECMSPSW  PC_ENT              FR  68.0  80.2
# 10    A    10-49  C10-S951_X_K  E_SECMSPSW  PC_ENT              DE  82.7  87.2
# ...

# %% [markdown]
# ### Indicator 3.9 - Enterprises: ICT security policy

# %%
code = 'ISOC_CISCE_RA'

# %%
my_filter_pars = {'size_emp': 'GE10', 'indic_is': ['E_SECPOL2'], 'unit':'PC_ENT', 'geo': countries, 'startPeriod': 2019, 'endPeriod':2019}
data = eurostat.get_data_df(code, filter_pars=my_filter_pars)

# %%
data
# Out:
#    freq size_emp       nace_r2   indic_is    unit geo\TIME_PERIOD  2019
# 0     A     GE10  C10-S951_X_K  E_SECPOL2  PC_ENT              AT  36.2
# 1     A     GE10  C10-S951_X_K  E_SECPOL2  PC_ENT              BE  34.2
# 2     A     GE10  C10-S951_X_K  E_SECPOL2  PC_ENT              BG  17.6
# 3     A     GE10  C10-S951_X_K  E_SECPOL2  PC_ENT              HR  41.2
# 4     A     GE10  C10-S951_X_K  E_SECPOL2  PC_ENT              CY  31.8
# 5     A     GE10  C10-S951_X_K  E_SECPOL2  PC_ENT              CZ  32.1
# 6     A     GE10  C10-S951_X_K  E_SECPOL2  PC_ENT              DK  55.6
# 7     A     GE10  C10-S951_X_K  E_SECPOL2  PC_ENT              EE  27.3
# 8     A     GE10  C10-S951_X_K  E_SECPOL2  PC_ENT              FI  43.5
# 9     A     GE10  C10-S951_X_K  E_SECPOL2  PC_ENT              FR  25.7
# 10    A     GE10  C10-S951_X_K  E_SECPOL2  PC_ENT              DE  37.3
# 11    A     GE10  C10-S951_X_K  E_SECPOL2  PC_ENT              EL  14.5
# ...

# %%
my_filter_pars = {'size_emp': '10-249', 'indic_is': ['E_SECPOL2'], 'unit':'PC_ENT', 'geo': countries, 'startPeriod': 2019, 'endPeriod':2022}
data = eurostat.get_data_df(code, filter_pars=my_filter_pars)

# %%
data
# Out:
#    freq size_emp       nace_r2   indic_is    unit geo\TIME_PERIOD  2019  2022
# 0     A   10-249  C10-S951_X_K  E_SECPOL2  PC_ENT              AT  34.9  30.7
# 1     A   10-249  C10-S951_X_K  E_SECPOL2  PC_ENT              BE  32.6  32.6
# 2     A   10-249  C10-S951_X_K  E_SECPOL2  PC_ENT              BG  16.8  20.8
# 3     A   10-249  C10-S951_X_K  E_SECPOL2  PC_ENT              HR  40.2  47.4
# 4     A   10-249  C10-S951_X_K  E_SECPOL2  PC_ENT              CY  31.1  30.1
# 5     A   10-249  C10-S951_X_K  E_SECPOL2  PC_ENT              CZ  30.3  23.6
# 6     A   10-249  C10-S951_X_K  E_SECPOL2  PC_ENT              DK  54.4  54.2
# 7     A   10-249  C10-S951_X_K  E_SECPOL2  PC_ENT              EE  26.6  35.7
# 8     A   10-249  C10-S951_X_K  E_SECPOL2  PC_ENT              FI  42.1  56.3
# 9     A   10-249  C10-S951_X_K  E_SECPOL2  PC_ENT              FR  24.4  19.5
# 10    A   10-249  C10-S951_X_K  E_SECPOL2  PC_ENT              DE  35.8  34.1
# ...

# %% [markdown]
# ### Indicator 3.1 - Enterprises: Staff Awareness

# %%
code = 'ISOC_CISCE_RA'

# %%
my_filter_pars = {'size_emp': 'GE10', 'indic_is': ['E_SECAWANY'], 'unit':'PC_ENT', 'geo': countries, 'startPeriod': 2019, 'endPeriod':2019}
data = eurostat.get_data_df(code, filter_pars=my_filter_pars)

# %%
data
# Out:
#    freq size_emp       nace_r2    indic_is    unit geo\TIME_PERIOD  2019
# 0     A     GE10  C10-S951_X_K  E_SECAWANY  PC_ENT              AT  63.2
# 1     A     GE10  C10-S951_X_K  E_SECAWANY  PC_ENT              BE  57.3
# 2     A     GE10  C10-S951_X_K  E_SECAWANY  PC_ENT              BG  51.0
# 3     A     GE10  C10-S951_X_K  E_SECAWANY  PC_ENT              HR  46.5
# 4     A     GE10  C10-S951_X_K  E_SECAWANY  PC_ENT              CY  59.3
# 5     A     GE10  C10-S951_X_K  E_SECAWANY  PC_ENT              CZ  75.6
# 6     A     GE10  C10-S951_X_K  E_SECAWANY  PC_ENT              DK  70.5
# 7     A     GE10  C10-S951_X_K  E_SECAWANY  PC_ENT              EE  55.3
# 8     A     GE10  C10-S951_X_K  E_SECAWANY  PC_ENT              FI  65.9
# 9     A     GE10  C10-S951_X_K  E_SECAWANY  PC_ENT              FR  54.5
# 10    A     GE10  C10-S951_X_K  E_SECAWANY  PC_ENT              DE  67.6
# 11    A     GE10  C10-S951_X_K  E_SECAWANY  PC_ENT              EL  33.3
# ...

# %%
my_filter_pars = {'size_emp': '10-249', 'indic_is': ['E_SECAWANY'], 'unit':'PC_ENT', 'geo': countries, 'startPeriod': 2019, 'endPeriod':2022}
data = eurostat.get_data_df(code, filter_pars=my_filter_pars)

# %%
data
# Out:
#    freq size_emp       nace_r2    indic_is    unit geo\TIME_PERIOD  2019  2022
# 0     A   10-249  C10-S951_X_K  E_SECAWANY  PC_ENT              AT  62.3  60.1
# 1     A   10-249  C10-S951_X_K  E_SECAWANY  PC_ENT              BE  56.2  52.4
# 2     A   10-249  C10-S951_X_K  E_SECAWANY  PC_ENT              BG  50.3  47.0
# 3     A   10-249  C10-S951_X_K  E_SECAWANY  PC_ENT              HR  45.4  36.9
# 4     A   10-249  C10-S951_X_K  E_SECAWANY  PC_ENT              CY  58.7  50.8
# 5     A   10-249  C10-S951_X_K  E_SECAWANY  PC_ENT              CZ  74.8  74.1
# 6     A   10-249  C10-S951_X_K  E_SECAWANY  PC_ENT              DK  69.7  69.3
# 7     A   10-249  C10-S951_X_K  E_SECAWANY  PC_ENT              EE  54.5  60.5
# 8     A   10-249  C10-S951_X_K  E_SECAWANY  PC_ENT              FI  64.9  66.3
# 9     A   10-249  C10-S951_X_K  E_SECAWANY  PC_ENT              FR  53.5  45.7
# 10    A   10-249  C10-S951_X_K  E_SECAWANY  PC_ENT              DE  66.7  67.1
# ...

# %% [markdown]
# ### Indicator 3.11 - Security Incidents: Unavailability of ICT Services (All Enterprises)

# %%
code = 'ISOC_CISCE_IC'
pars = eurostat.get_pars(code)

# %%
pars
# Out:
# ['freq', 'size_emp', 'nace_r2', 'indic_is', 'unit', 'geo']

# %%
eurostat.get_par_values(code, 'size_emp')
# Out:
# ['0_1',
#  '0-9',
#  '1-4',
#  '1-9',
#  '2-9',
#  '5-9',
#  '10-49',
#  '10-249',
#  'GE10',
#  '50-249',
#  'GE250']

# %%
eurostat.get_par_values(code, 'indic_is')
# Out:
# ['E_SEC2IUSVF',
#  'E_SEC2IUSVA',
#  'E_SEC2IUSV',
#  'E_SEC2IDCDF',
#  'E_SEC2IDCDA',
#  'E_SEC2IDCD',
#  'E_SEC2ICNFA',
#  'E_SEC2ICNFF',
#  'E_SEC2ICNF',
#  'E_SEC2IANY',
#  'E_SEC2IGE3',
#  'E_SECI2USV',
#  'E_SECI2DCD',
#  'E_SECI2CNF',
#  'E_SECI2ANY',
#  'E_SECI2NONE',
#  'E_SECIUSF',
#  'E_SECIUSA',
#  'E_SECIDD',
#  'E_SECICNFA',
#  'E_SECIANY',
#  'E_SECINONE',
#  'E_SECICNFE',
#  'E_SECINS']

# %%
my_filter_pars = {'size_emp': 'GE10', 'indic_is': ['E_SECI2USV'], 'unit':'PC_ENT', 'geo': countries, 'startPeriod': 2019, 'endPeriod':2019}
data = eurostat.get_data_df(code, filter_pars=my_filter_pars)

# %%
data
# Out:
#    freq size_emp       nace_r2    indic_is    unit geo\TIME_PERIOD  2019
# 0     A     GE10  C10-S951_X_K  E_SECI2USV  PC_ENT              AT   9.1
# 1     A     GE10  C10-S951_X_K  E_SECI2USV  PC_ENT              BE  19.9
# 2     A     GE10  C10-S951_X_K  E_SECI2USV  PC_ENT              BG  12.6
# 3     A     GE10  C10-S951_X_K  E_SECI2USV  PC_ENT              HR  16.4
# 4     A     GE10  C10-S951_X_K  E_SECI2USV  PC_ENT              CY   8.2
# 5     A     GE10  C10-S951_X_K  E_SECI2USV  PC_ENT              CZ  16.5
# 6     A     GE10  C10-S951_X_K  E_SECI2USV  PC_ENT              DK   6.7
# 7     A     GE10  C10-S951_X_K  E_SECI2USV  PC_ENT              EE   5.5
# 8     A     GE10  C10-S951_X_K  E_SECI2USV  PC_ENT              FI  13.3
# 9     A     GE10  C10-S951_X_K  E_SECI2USV  PC_ENT              FR  11.8
# 10    A     GE10  C10-S951_X_K  E_SECI2USV  PC_ENT              DE   8.0
# 11    A     GE10  C10-S951_X_K  E_SECI2USV  PC_ENT              EL   4.5
# ...

# %% [markdown]
# ### Indicator 3.12 - Security Incidents: Destruction or corruption of data (All Enterprises)

# %%
my_filter_pars = {'size_emp': 'GE10', 'indic_is': ['E_SEC2IDCD'], 'unit':'PC_ENT', 'geo': countries, 'startPeriod': 2019, 'endPeriod':2019}
data = eurostat.get_data_df(code, filter_pars=my_filter_pars)

# %%
data
# Out:
#    freq size_emp       nace_r2    indic_is    unit geo\TIME_PERIOD  2019
# 0     A     GE10  C10-S951_X_K  E_SECI2DCD  PC_ENT              AT   4.9
# 1     A     GE10  C10-S951_X_K  E_SECI2DCD  PC_ENT              BE   6.5
# 2     A     GE10  C10-S951_X_K  E_SECI2DCD  PC_ENT              BG   7.5
# 3     A     GE10  C10-S951_X_K  E_SECI2DCD  PC_ENT              HR   6.0
# 4     A     GE10  C10-S951_X_K  E_SECI2DCD  PC_ENT              CY   6.5
# 5     A     GE10  C10-S951_X_K  E_SECI2DCD  PC_ENT              CZ   9.2
# 6     A     GE10  C10-S951_X_K  E_SECI2DCD  PC_ENT              DK   3.7
# 7     A     GE10  C10-S951_X_K  E_SECI2DCD  PC_ENT              EE   3.4
# 8     A     GE10  C10-S951_X_K  E_SECI2DCD  PC_ENT              FI   5.4
# 9     A     GE10  C10-S951_X_K  E_SECI2DCD  PC_ENT              FR   6.2
# 10    A     GE10  C10-S951_X_K  E_SECI2DCD  PC_ENT              DE   5.4
# 11    A     GE10  C10-S951_X_K  E_SECI2DCD  PC_ENT              EL   4.2
# ...

# %% [markdown]
# ### Indicator 3.13 - Security Incidents: Disclosure of confidential data (All Enterprises)

# %%
my_filter_pars = {'size_emp': 'GE10', 'indic_is': ['E_SECI2CNF'], 'unit':'PC_ENT', 'geo': countries, 'startPeriod': 2019, 'endPeriod':2019}
data = eurostat.get_data_df(code, filter_pars=my_filter_pars)

# %%
data
# Out:
#    freq size_emp       nace_r2    indic_is    unit geo\TIME_PERIOD  2019
# 0     A     GE10  C10-S951_X_K  E_SECI2CNF  PC_ENT              AT   1.8
# 1     A     GE10  C10-S951_X_K  E_SECI2CNF  PC_ENT              BE   2.0
# 2     A     GE10  C10-S951_X_K  E_SECI2CNF  PC_ENT              BG   1.5
# 3     A     GE10  C10-S951_X_K  E_SECI2CNF  PC_ENT              HR   1.6
# 4     A     GE10  C10-S951_X_K  E_SECI2CNF  PC_ENT              CY   2.4
# 5     A     GE10  C10-S951_X_K  E_SECI2CNF  PC_ENT              CZ   1.4
# 6     A     GE10  C10-S951_X_K  E_SECI2CNF  PC_ENT              DK   2.9
# 7     A     GE10  C10-S951_X_K  E_SECI2CNF  PC_ENT              EE   2.7
# 8     A     GE10  C10-S951_X_K  E_SECI2CNF  PC_ENT              FI   3.9
# 9     A     GE10  C10-S951_X_K  E_SECI2CNF  PC_ENT              FR   2.1
# 10    A     GE10  C10-S951_X_K  E_SECI2CNF  PC_ENT              DE   1.4
# 11    A     GE10  C10-S951_X_K  E_SECI2CNF  PC_ENT              EL   1.4
# ...

# %% [markdown]
# ### Indicator 3.14 - Security Incidents: Unavailability of ICT Services (SME)

# %%
# eurostat.get_par_values(code, 'indic_is')

# %%
my_filter_pars = {'size_emp': '10-249', 'indic_is': ['E_SECI2USV'], 'unit':'PC_ENT', 'geo': countries, 'startPeriod': 2019, 'endPeriod':2019}
data = eurostat.get_data_df(code, filter_pars=my_filter_pars)

# %%
data
# Out:
#    freq size_emp       nace_r2    indic_is    unit geo\TIME_PERIOD  2019
# 0     A   10-249  C10-S951_X_K  E_SECI2USV  PC_ENT              AT   9.0
# 1     A   10-249  C10-S951_X_K  E_SECI2USV  PC_ENT              BE  19.6
# 2     A   10-249  C10-S951_X_K  E_SECI2USV  PC_ENT              BG  12.3
# 3     A   10-249  C10-S951_X_K  E_SECI2USV  PC_ENT              HR  16.4
# 4     A   10-249  C10-S951_X_K  E_SECI2USV  PC_ENT              CY   8.2
# 5     A   10-249  C10-S951_X_K  E_SECI2USV  PC_ENT              CZ  15.9
# 6     A   10-249  C10-S951_X_K  E_SECI2USV  PC_ENT              DK   6.4
# 7     A   10-249  C10-S951_X_K  E_SECI2USV  PC_ENT              EE   5.4
# 8     A   10-249  C10-S951_X_K  E_SECI2USV  PC_ENT              FI  12.8
# 9     A   10-249  C10-S951_X_K  E_SECI2USV  PC_ENT              FR  11.5
# 10    A   10-249  C10-S951_X_K  E_SECI2USV  PC_ENT              DE   7.9
# 11    A   10-249  C10-S951_X_K  E_SECI2USV  PC_ENT              EL   4.4
# ...

# %% [markdown]
# ### 3.15 - Security Incidents: Destruction or corruption of data (SME)

# %%
my_filter_pars = {'size_emp': '10-249', 'indic_is': ['E_SECI2DCD'], 'unit':'PC_ENT', 'geo': countries, 'startPeriod': 2019, 'endPeriod':2019}
data = eurostat.get_data_df(code, filter_pars=my_filter_pars)

# %%
data
# Out:
#    freq size_emp       nace_r2    indic_is    unit geo\TIME_PERIOD  2019
# 0     A   10-249  C10-S951_X_K  E_SECI2DCD  PC_ENT              AT   4.9
# 1     A   10-249  C10-S951_X_K  E_SECI2DCD  PC_ENT              BE   6.4
# 2     A   10-249  C10-S951_X_K  E_SECI2DCD  PC_ENT              BG   7.3
# 3     A   10-249  C10-S951_X_K  E_SECI2DCD  PC_ENT              HR   5.9
# 4     A   10-249  C10-S951_X_K  E_SECI2DCD  PC_ENT              CY   6.5
# 5     A   10-249  C10-S951_X_K  E_SECI2DCD  PC_ENT              CZ   8.9
# 6     A   10-249  C10-S951_X_K  E_SECI2DCD  PC_ENT              DK   3.6
# 7     A   10-249  C10-S951_X_K  E_SECI2DCD  PC_ENT              EE   3.3
# 8     A   10-249  C10-S951_X_K  E_SECI2DCD  PC_ENT              FI   5.2
# 9     A   10-249  C10-S951_X_K  E_SECI2DCD  PC_ENT              FR   6.0
# 10    A   10-249  C10-S951_X_K  E_SECI2DCD  PC_ENT              DE   5.4
# 11    A   10-249  C10-S951_X_K  E_SECI2DCD  PC_ENT              EL   4.2
# ...

# %% [markdown]
# ### Indicator 3.16 - Security Incidents: Disclosure of confidential data (SME)

# %%
my_filter_pars = {'size_emp': '10-249', 'indic_is': ['E_SECI2CNF'], 'unit':'PC_ENT', 'geo': countries, 'startPeriod': 2019, 'endPeriod':2019}
data = eurostat.get_data_df(code, filter_pars=my_filter_pars)

# %%
data
# Out:
#    freq size_emp       nace_r2    indic_is    unit geo\TIME_PERIOD  2019
# 0     A   10-249  C10-S951_X_K  E_SECI2CNF  PC_ENT              AT   1.7
# 1     A   10-249  C10-S951_X_K  E_SECI2CNF  PC_ENT              BE   1.8
# 2     A   10-249  C10-S951_X_K  E_SECI2CNF  PC_ENT              BG   1.4
# 3     A   10-249  C10-S951_X_K  E_SECI2CNF  PC_ENT              HR   1.6
# 4     A   10-249  C10-S951_X_K  E_SECI2CNF  PC_ENT              CY   2.5
# 5     A   10-249  C10-S951_X_K  E_SECI2CNF  PC_ENT              CZ   1.3
# 6     A   10-249  C10-S951_X_K  E_SECI2CNF  PC_ENT              DK   2.6
# 7     A   10-249  C10-S951_X_K  E_SECI2CNF  PC_ENT              EE   2.6
# 8     A   10-249  C10-S951_X_K  E_SECI2CNF  PC_ENT              FI   3.5
# 9     A   10-249  C10-S951_X_K  E_SECI2CNF  PC_ENT              FR   1.9
# 10    A   10-249  C10-S951_X_K  E_SECI2CNF  PC_ENT              DE   1.4
# 11    A   10-249  C10-S951_X_K  E_SECI2CNF  PC_ENT              EL   1.4
# ...

# %% [markdown]
# ### Share of enterprises that buy security software applications as Cloud Computing Service

# %%
code='ISOC_CICCE_USE'

# %%
my_filter_pars = {'size_emp': 'GE10', 'indic_is': ['E_CC_PSEC'], 'unit':'PC_ENT', 'geo': countries, 'startPeriod': 2021, 'endPeriod':2021}
data = eurostat.get_data_df(code, filter_pars=my_filter_pars)

# %%
data
# Out:
#    freq size_emp       nace_r2   indic_is    unit geo\TIME_PERIOD  2021
# 0     A     GE10  C10-S951_X_K  E_CC_PSEC  PC_ENT              AT  19.7
# 1     A     GE10  C10-S951_X_K  E_CC_PSEC  PC_ENT              BE  34.3
# 2     A     GE10  C10-S951_X_K  E_CC_PSEC  PC_ENT              BG   5.7
# 3     A     GE10  C10-S951_X_K  E_CC_PSEC  PC_ENT              HR  25.5
# 4     A     GE10  C10-S951_X_K  E_CC_PSEC  PC_ENT              CY  35.8
# 5     A     GE10  C10-S951_X_K  E_CC_PSEC  PC_ENT              CZ  34.2
# 6     A     GE10  C10-S951_X_K  E_CC_PSEC  PC_ENT              DK  51.7
# 7     A     GE10  C10-S951_X_K  E_CC_PSEC  PC_ENT              EE  25.5
# 8     A     GE10  C10-S951_X_K  E_CC_PSEC  PC_ENT              FI  48.8
# 9     A     GE10  C10-S951_X_K  E_CC_PSEC  PC_ENT              FR  15.0
# 10    A     GE10  C10-S951_X_K  E_CC_PSEC  PC_ENT              DE  20.0
# 11    A     GE10  C10-S951_X_K  E_CC_PSEC  PC_ENT              EL  11.5
# ...

# %% [markdown]
# ### Share of enterprises that use AI technologies for ICT security

# %%
code='ISOC_EB_AI'

# %%
my_filter_pars = {'size_emp': 'GE10', 'indic_is': ['E_AI_PITS'], 'unit':'PC_ENT', 'geo': countries, 'startPeriod': 2021, 'endPeriod':2021}
data = eurostat.get_data_df(code, filter_pars=my_filter_pars)

# %%
data
# Out:
#    freq size_emp       nace_r2   indic_is    unit geo\TIME_PERIOD  2021
# 0     A     GE10  C10-S951_X_K  E_AI_PITS  PC_ENT              AT   1.3
# 1     A     GE10  C10-S951_X_K  E_AI_PITS  PC_ENT              BE   3.8
# 2     A     GE10  C10-S951_X_K  E_AI_PITS  PC_ENT              BG   0.5
# 3     A     GE10  C10-S951_X_K  E_AI_PITS  PC_ENT              HR   1.9
# 4     A     GE10  C10-S951_X_K  E_AI_PITS  PC_ENT              CY   1.3
# 5     A     GE10  C10-S951_X_K  E_AI_PITS  PC_ENT              CZ   1.7
# 6     A     GE10  C10-S951_X_K  E_AI_PITS  PC_ENT              DK   6.8
# 7     A     GE10  C10-S951_X_K  E_AI_PITS  PC_ENT              EE   0.6
# 8     A     GE10  C10-S951_X_K  E_AI_PITS  PC_ENT              FI   2.9
# 9     A     GE10  C10-S951_X_K  E_AI_PITS  PC_ENT              FR   1.4
# 10    A     GE10  C10-S951_X_K  E_AI_PITS  PC_ENT              DE   2.1
# 11    A     GE10  C10-S951_X_K  E_AI_PITS  PC_ENT              EL   1.0
# ...

# %% [markdown]
# ### Population

# %%
code = 'tps00001'
pars = eurostat.get_pars(code)

# %%
eurostat.get_par_values(code, 'indic_de')
# Out:
# ['JAN']

# %%
pars
# Out:
# ['freq', 'indic_de', 'geo']

# %%
my_filter_pars = { 'geo': countries, 'startPeriod': 2022, 'endPeriod':2022}
data = eurostat.get_data_df(code, filter_pars=my_filter_pars)

# %%
data
# Out:
#    freq indic_de geo\TIME_PERIOD        2022
# 0     A      JAN              AT   8978929.0
# 1     A      JAN              BE  11631136.0
# 2     A      JAN              BG   6838937.0
# 3     A      JAN              HR   3879074.0
# 4     A      JAN              CY    904705.0
# 5     A      JAN              CZ  10516707.0
# 6     A      JAN              DK   5873420.0
# 7     A      JAN              EE   1331796.0
# 8     A      JAN              FI   5548241.0
# 9     A      JAN              FR  67842582.0
# 10    A      JAN              DE  83237124.0
# 11    A      JAN              EL  10603810.0
# 12    A      JAN              HU   9689010.0
# 13    A      JAN              IE   5060005.0
# 14    A      JAN              IT  58983122.0
# 15    A      JAN              LV   1875757.0
# 16    A      JAN              LT   2805998.0
# 17    A      JAN              LU    645397.0
# 18    A      JAN              MT    520971.0
# 19    A      JAN              NL  17590672.0
# ...
